# %%
import pandas as pd  # Importing pandas
import matplotlib.pyplot as plt  # Importing matplotlib for visualization

df = pd.read_csv('../data/pokemon_data.csv') 
df  # This shows the DataFrame in the output
df.head() # by default the command returns first five rows of the DataFrame
# Out:
#    dexnum        name  generation  type1   type2         species  height  \
# 0       1   Bulbasaur           1  Grass  Poison    Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison    Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison    Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN  Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN   Flame Pokémon     1.1
#
#    weight  ability1     ability2  ... catch_rate  base_friendship  base_exp  \
# 0     6.9  Overgrow  Chlorophyll  ...         45               50        64
# 1    13.0  Overgrow  Chlorophyll  ...         45               50       142
# 2   100.0  Overgrow  Chlorophyll  ...         45               50       236
# 3     8.5     Blaze  Solar Power  ...         45               50        62
# 4    19.0     Blaze  Solar Power  ...         45               50       142
#
# ...

# %%
df.head().plot.bar() # the bar chart of heads of the DataFrame
# Out:
# <Axes: >

# %%
df.tail(10) # the function returns last ten rows of the DataFrame
# Out:
#       dexnum          name  generation     type1    type2  \
# 1015    1016   Fezandipiti           9    Poison    Fairy
# 1016    1017       Ogerpon           9     Grass      NaN
# 1017    1018    Archaludon           9     Steel   Dragon
# 1018    1019     Hydrapple           9     Grass   Dragon
# 1019    1020  Gouging Fire           9      Fire   Dragon
# 1020    1021   Raging Bolt           9  Electric   Dragon
# 1021    1022  Iron Boulder           9      Rock  Psychic
# 1022    1023    Iron Crown           9     Steel  Psychic
# 1023    1024     Terapagos           9    Normal      NaN
# 1024    1025     Pecharunt           9    Poison    Ghost
#
#                   species  height  weight          ability1       ability2  \
# 1015     Retainer Pokémon     1.4    30.1       Toxic Chain     Technician
# 1016         Mask Pokémon     1.2    39.8           Defiant  Embody Aspect
# 1017        Alloy Pokémon     2.0    60.0           Stamina         Sturdy
# ...

# %%
print(df.head(10) )# the function returns first ten rows of the DataFrame
# Out:
#    dexnum        name  generation  type1   type2              species  height  \
# 0       1   Bulbasaur           1  Grass  Poison         Seed Pokémon     0.7
# 1       2     Ivysaur           1  Grass  Poison         Seed Pokémon     1.0
# 2       3    Venusaur           1  Grass  Poison         Seed Pokémon     2.0
# 3       4  Charmander           1   Fire     NaN       Lizard Pokémon     0.6
# 4       5  Charmeleon           1   Fire     NaN        Flame Pokémon     1.1
# 5       6   Charizard           1   Fire  Flying        Flame Pokémon     1.7
# 6       7    Squirtle           1  Water     NaN  Tiny Turtle Pokémon     0.5
# 7       8   Wartortle           1  Water     NaN       Turtle Pokémon     1.0
# 8       9   Blastoise           1  Water     NaN    Shellfish Pokémon     1.6
# 9      10    Caterpie           1    Bug     NaN         Worm Pokémon     0.3
#
#    weight     ability1     ability2  ... catch_rate  base_friendship  \
# ...

# %%
print( df.info()) # provides a full information of the entire DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dexnum           1025 non-null   int64
#  1   name             1025 non-null   object
#  2   generation       1025 non-null   int64
#  3   type1            1025 non-null   object
#  4   type2            526 non-null    object
#  5   species          1025 non-null   object
#  6   height           1025 non-null   float64
#  7   weight           1025 non-null   float64
#  8   ability1         1025 non-null   object
#  9   ability2         858 non-null    object
#  10  hidden_ability   530 non-null    object
#  11  hp               1025 non-null   int64
#  12  attack           1025 non-null   int64
#  13  defense          1025 non-null   int64
#  14  sp_atk           1025 non-null   int64
#  15  sp_def           1025 non-null   int64
#  16  speed            1025 non-null   int64
# ...

# %%
df.sample(5) # In this sample, the function returns 5 random subsets
# Out:
#      dexnum       name  generation   type1     type2              species  \
# 941     942   Maschiff           9    Dark       NaN       Rascal Pokémon
# 710     711  Gourgeist           6   Ghost     Grass      Pumpkin Pokémon
# 643     644     Zekrom           5  Dragon  Electric   Deep Black Pokémon
# 467     468   Togekiss           4   Fairy    Flying      Jubilee Pokémon
# 545     546   Cottonee           5   Grass     Fairy  Cotton Puff Pokémon
#
#      height  weight    ability1      ability2  ... catch_rate  \
# 941     0.5    16.0  Intimidate      Run Away  ...        150
# 710     0.9    12.5      Pickup         Frisk  ...         60
# 643     2.9   345.0    Teravolt           NaN  ...          3
# 467     1.5    38.0      Hustle  Serene Grace  ...         30
# 545     0.3     0.6   Prankster   Infiltrator  ...        190
#
#      base_friendship  base_exp  growth_rate    egg_group1  egg_group2  \
# 941               50        68  Medium Slow         Field         NaN
# ...

# %%
df.columns
# Out:
# Index(['dexnum', 'name', 'generation', 'type1', 'type2', 'species', 'height',
#        'weight', 'ability1', 'ability2', 'hidden_ability', 'hp', 'attack',
#        'defense', 'sp_atk', 'sp_def', 'speed', 'total', 'ev_yield',
#        'catch_rate', 'base_friendship', 'base_exp', 'growth_rate',
#        'egg_group1', 'egg_group2', 'percent_male', 'percent_female',
#        'egg_cycles', 'special_group'],
#       dtype='object')

# %% [markdown]
#  If we want to see the value of rows of the DataFrame in 1D list, here is the index method
#  which shows the row number of the DataFrame.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %%
df.describe() # to provide some descriptive statistics of columns, e.g. mean, quartiles, standard deviation etc. in fast way
# Out:
#             dexnum   generation       height       weight           hp  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean    513.000000     4.741463     1.211610    66.981659    70.184390
# std     296.036315     2.633633     1.248167   121.275372    26.631054
# min       1.000000     1.000000     0.100000     0.100000     1.000000
# 25%     257.000000     3.000000     0.500000     8.500000    50.000000
# 50%     513.000000     5.000000     1.000000    28.000000    68.000000
# 75%     769.000000     7.000000     1.500000    70.000000    85.000000
# max    1025.000000     9.000000    20.000000   999.900000   255.000000
#
#             attack      defense       sp_atk       sp_def        speed  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean     77.521951    72.507317    70.080976    70.205854    67.186341
# std      29.782541    29.286972    29.658378    26.639329    28.717227
# ...

# %%
df[['hp', 'attack']].describe() # In our case we are considering "HP" and "Attac
# Out:
#                 hp       attack
# count  1025.000000  1025.000000
# mean     70.184390    77.521951
# std      26.631054    29.782541
# min       1.000000     5.000000
# 25%      50.000000    55.000000
# 50%      68.000000    75.000000
# 75%      85.000000   100.000000
# max     255.000000   181.000000

# %%
df['hp'].plot.hist() # Shows the histogram of DataFrame in "HP" column
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df.columns[:4]] # Here we can see the information of rows only for the first
# Out:
#       dexnum          name  generation     type1
# 0          1     Bulbasaur           1     Grass
# 1          2       Ivysaur           1     Grass
# 2          3      Venusaur           1     Grass
# 3          4    Charmander           1      Fire
# 4          5    Charmeleon           1      Fire
# ...      ...           ...         ...       ...
# 1020    1021   Raging Bolt           9  Electric
# 1021    1022  Iron Boulder           9      Rock
# 1022    1023    Iron Crown           9     Steel
# 1023    1024     Terapagos           9    Normal
# 1024    1025     Pecharunt           9    Poison
#
# [1025 rows x 4 columns]

# %%
df.select_dtypes('int') # here we see rows only with filtering columns as intege
# Out:
#       dexnum  generation   hp  attack  defense  sp_atk  sp_def  speed  total  \
# 0          1           1   45      49       49      65      65     45    318
# 1          2           1   60      62       63      80      80     60    405
# 2          3           1   80      82       83     100     100     80    525
# 3          4           1   39      52       43      60      50     65    309
# 4          5           1   58      64       58      80      65     80    405
# ...      ...         ...  ...     ...      ...     ...     ...    ...    ...
# 1020    1021           9  125      73       91     137      89     75    590
# 1021    1022           9   90     120       80      68     108    124    590
# 1022    1023           9   90      72      100     122     108     98    590
# 1023    1024           9   90      65       85      65      85     60    450
# 1024    1025           9   88      88      160      88      88     88    600
#
#       catch_rate
# 0             45
# ...
