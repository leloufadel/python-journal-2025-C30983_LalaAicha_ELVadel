# %%
import pandas as pd  # Importing pandas
import matplotlib.pyplot as plt  # 

df = pd.read_csv('../data/pokemon_data.csv')

# %%
df.iloc[2, 4] # Here we can see the information from second row and fourth␣
# Out:
# 'Poison'

# %%
df.iloc[:5, :5] # Here is the information of first five rows with first five
# Out:
#    dexnum        name  generation  type1   type2
# 0       1   Bulbasaur           1  Grass  Poison
# 1       2     Ivysaur           1  Grass  Poison
# 2       3    Venusaur           1  Grass  Poison
# 3       4  Charmander           1   Fire     NaN
# 4       5  Charmeleon           1   Fire     NaN

# %%
df.iloc[:5, 1:5].plot.bar() # Bar char of the DataFrame provided abov
# Out:
# <Axes: >

# %%
df.iloc[[5]] # single row as a dataFrame
# Out:
#    dexnum       name  generation type1   type2        species  height  weight  \
# 5       6  Charizard           1  Fire  Flying  Flame Pokémon     1.7    90.5
#
#   ability1     ability2  ... catch_rate  base_friendship  base_exp  \
# 5    Blaze  Solar Power  ...         45               50       267
#
#    growth_rate  egg_group1  egg_group2  percent_male  percent_female  \
# 5  Medium Slow     Dragon      Monster          87.5            12.5
#
#   egg_cycles  special_group
# 5         20       Ordinary
#
# [1 rows x 29 columns]

# %%
df.iloc[:, 1] # Filters all rows and "Name" column as Series
# Out:
# 0          Bulbasaur
# 1            Ivysaur
# 2           Venusaur
# 3         Charmander
# 4         Charmeleon
#             ...
# 1020     Raging Bolt
# 1021    Iron Boulder
# 1022      Iron Crown
# 1023       Terapagos
# 1024       Pecharunt
# Name: name, Length: 1025, dtype: object

# %%
df.iloc[:, [1, 6]] # Filters all rows and "Name" and "Defense" columns as␣↪DataFrame
# Out:
#               name  height
# 0        Bulbasaur     0.7
# 1          Ivysaur     1.0
# 2         Venusaur     2.0
# 3       Charmander     0.6
# 4       Charmeleon     1.1
# ...            ...     ...
# 1020   Raging Bolt     5.2
# 1021  Iron Boulder     1.5
# 1022    Iron Crown     1.6
# 1023     Terapagos     0.2
# 1024     Pecharunt     0.3
#
# [1025 rows x 2 columns]

# %%
df.iloc[:, [1, 6]].plot.hist() # Histogram of defence data
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Query() method

# %%
df.query('(hp > 40) and (attack < 100)')
# Out:
#       dexnum         name  generation     type1    type2              species  \
# 0          1    Bulbasaur           1     Grass   Poison         Seed Pokémon
# 1          2      Ivysaur           1     Grass   Poison         Seed Pokémon
# 2          3     Venusaur           1     Grass   Poison         Seed Pokémon
# 4          5   Charmeleon           1      Fire      NaN        Flame Pokémon
# 5          6    Charizard           1      Fire   Flying        Flame Pokémon
# ...      ...          ...         ...       ...      ...                  ...
# 1018    1019    Hydrapple           9     Grass   Dragon                    —
# 1020    1021  Raging Bolt           9  Electric   Dragon      Paradox Pokémon
# 1022    1023   Iron Crown           9     Steel  Psychic      Paradox Pokémon
# 1023    1024    Terapagos           9    Normal      NaN         Tera Pokémon
# 1024    1025    Pecharunt           9    Poison    Ghost  Subjugation Pokémon
#
# ...

# %%
min_hp = 70
df.query('(hp > @min_hp)')
# Out:
#       dexnum          name  generation     type1    type2  \
# 2          3      Venusaur           1     Grass   Poison
# 5          6     Charizard           1      Fire   Flying
# 8          9     Blastoise           1     Water      NaN
# 17        18       Pidgeot           1    Normal   Flying
# 27        28     Sandslash           1    Ground      NaN
# ...      ...           ...         ...       ...      ...
# 1020    1021   Raging Bolt           9  Electric   Dragon
# 1021    1022  Iron Boulder           9      Rock  Psychic
# 1022    1023    Iron Crown           9     Steel  Psychic
# 1023    1024     Terapagos           9    Normal      NaN
# 1024    1025     Pecharunt           9    Poison    Ghost
#
#                   species  height  weight          ability1      ability2  \
# 2            Seed Pokémon     2.0   100.0          Overgrow   Chlorophyll
# 5           Flame Pokémon     1.7    90.5             Blaze   Solar Power
# ...
